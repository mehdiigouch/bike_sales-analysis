# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt 
import seaborn as sb
from pathlib import Path
import pytest

# %%
PATH_ROOT  = Path.cwd().parent.parent
print(PATH_ROOT)
DATASET_ROOT = PATH_ROOT /"Sales.csv"
DATASET=pd.read_csv(DATASET_ROOT)
DATASET.head()
# Out:
# c:\Users\IGO\OneDrive\Bureau\DA PROJECTS\PROJECT  bike sales analysis
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  26/11/2013   26  November  2013            19     Youth (<25)
# 1  26/11/2015   26  November  2015            19     Youth (<25)
# 2  23/03/2014   23     March  2014            49  Adults (35-64)
# 3  23/03/2016   23     March  2016            49  Adults (35-64)
# 4  15/05/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
DATASET.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
import pandas as pd
#from utils.logs import section,logger
from pathlib import Path
import time


# ════════════════════════════════════════════════════════════
# STEP 1 — VALIDATE FILE EXISTS
# ════════════════════════════════════════════════════════════

def validate_file(file_path: str) -> Path:
    #section("STEP 1 — FILE VALIDATION")
    path = Path(file_path).resolve()

    # Check existence
    if not path.exists():
        #logger.error(f"File not found: {path}")
        raise FileNotFoundError(f" File not found: {path}")
    #logger.info(f" File found      : {path.name}")

    # Check extension
    if path.suffix.lower() != ".csv":
        raise ValueError(f" Expected a .csv file, got: '{path.suffix}'")
    #logger.info(f" File extension  : {path.suffix}")


    # Check file size
    size_kb = path.stat().st_size / 1024
    size_mb = size_kb / 1024
    #logger.info(f" File size       : {size_mb:.2f} MB ({size_kb:,.1f} KB)")
    if path.stat().st_size == 0:
        raise ValueError(" File is empty (0 bytes).")

    #logger.info(f" Full path       : {path}")

    return path

    


p=validate_file(DATASET_ROOT)
print(p)
# Out:
# C:\Users\IGO\OneDrive\Bureau\DA PROJECTS\PROJECT  bike sales analysis\Sales.csv

# %%
path = Path(DATASET_ROOT).resolve()
print(path)
path.exists()==True
# Out:
# C:\Users\IGO\OneDrive\Bureau\DA PROJECTS\PROJECT  bike sales analysis\Sales.csv
# True

# %%
missing_count = DATASET.isnull().sum()


print(missing_count)
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
n_dupes = DATASET.duplicated().sum()
print(f"Number of duplicate rows: {n_dupes}")

n_col = DATASET.columns.duplicated().sum()
print(f"Number of duplicate columns: {n_col}")

len(DATASET.columns)
# Out:
# Number of duplicate rows: 1000
# Number of duplicate columns: 0
# 18

# %%
num_df = DATASET.select_dtypes(include="number")
summary = num_df.describe().T
summary["range"]    = summary["max"] - summary["min"]
summary["cv%"]      = (summary["std"] / summary["mean"] * 100).round(2)  # Coefficient of variation
print(summary.round(2).to_string())
# Out:
#                    count     mean      std     min     25%     50%     75%      max    range     cv%
# Day             113036.0    15.67     8.78     1.0     8.0    16.0    23.0     31.0     30.0   56.06
# Year            113036.0  2014.40     1.27  2011.0  2013.0  2014.0  2016.0   2016.0      5.0    0.06
# Customer_Age    113036.0    35.92    11.02    17.0    28.0    35.0    43.0     87.0     70.0   30.69
# Order_Quantity  113036.0    11.90     9.56     1.0     2.0    10.0    20.0     32.0     31.0   80.34
# Unit_Cost       113036.0   267.30   549.84     1.0     2.0     9.0    42.0   2171.0   2170.0  205.70
# Unit_Price      113036.0   452.94   922.07     2.0     5.0    24.0    70.0   3578.0   3576.0  203.58
# Profit          113036.0   285.05   453.89   -30.0    29.0   101.0   358.0  15096.0  15126.0  159.23
# Cost            113036.0   469.32   884.87     1.0    28.0   108.0   432.0  42978.0  42977.0  188.54
# ...

# %%
DATASET["Age_Group"].unique()
# Out:
# array(['Youth (<25)', 'Adults (35-64)', 'Young Adults (25-34)',
#        'Seniors (64+)'], dtype=object)

# %%
DATASET.head(5)
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  26/11/2013   26  November  2013            19     Youth (<25)
# 1  26/11/2015   26  November  2015            19     Youth (<25)
# 2  23/03/2014   23     March  2014            49  Adults (35-64)
# 3  23/03/2016   23     March  2016            49  Adults (35-64)
# 4  15/05/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
f=DATASET["Sub_Category"].unique()
c=DATASET["Sub_Category"].nunique()

print(f,c)
# Out:
# ['Bike Racks' 'Bike Stands' 'Bottles and Cages' 'Caps' 'Cleaners'
#  'Fenders' 'Gloves' 'Helmets' 'Hydration Packs' 'Jerseys' 'Mountain Bikes'
#  'Road Bikes' 'Shorts' 'Socks' 'Tires and Tubes' 'Touring Bikes' 'Vests'] 17

# %%
DATASET.shape
# Out:
# (113036, 18)

# %%
DATASET.describe(include="all")
# Out:
#               Date            Day   Month           Year   Customer_Age  \
# count       113036  113036.000000  113036  113036.000000  113036.000000
# unique        1884            NaN      12            NaN            NaN
# top     01/03/2014            NaN    June            NaN            NaN
# freq           288            NaN   11234            NaN            NaN
# mean           NaN      15.665753     NaN    2014.401739      35.919212
# std            NaN       8.781567     NaN       1.272510      11.021936
# min            NaN       1.000000     NaN    2011.000000      17.000000
# 25%            NaN       8.000000     NaN    2013.000000      28.000000
# 50%            NaN      16.000000     NaN    2014.000000      35.000000
# 75%            NaN      23.000000     NaN    2016.000000      43.000000
# max            NaN      31.000000     NaN    2016.000000      87.000000
#
#              Age_Group Customer_Gender        Country       State  \
# ...
